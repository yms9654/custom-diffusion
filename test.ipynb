# %%
from diffusers import DiffusionPipeline

pipeline = DiffusionPipeline.from_pretrained("yms9654/wonderland-axe", use_auth_token="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")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/workspace/custom-diffusion/.venv/lib/python3.9/site-packages/huggingface_hub/utils/_errors.py:239, in hf_raise_for_status(response, endpoint_name)
#     238 try:
# --> 239     response.raise_for_status()
#     240 except HTTPError as e:
#
# File ~/workspace/custom-diffusion/.venv/lib/python3.9/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/yms9654/wonderland-axe/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...
